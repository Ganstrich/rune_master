# %%
from dofusapi import DofusAPI
from dataprocessor import DataProcessor
# from visualizer import EquipmentVisualizer
from utils import CacheManager
from collections import defaultdict
import numpy as np

# %%
equipments = DofusAPI.get_all_equipments()
# Out:
# ✅ 271 équipements récupérés avec succès

# %%
import pandas as pd

df = pd.DataFrame(equipments)

# %%
IOP = ['Bague Harre', 'Sangle Hynère', 'Bottes Antrin', 'Casque Keutumedi', 'Cape Aurale']

# %%
excluded_items = df['name'].isin(['Bottes Antrin'])
df[excluded_items]
# Out:
#      ankama_id                          type  level           name  \
# 164       8663  {'name': 'Bottes', 'id': 45}    100  Bottes Antrin
#
#                                                 recipe  \
# 164  [{'resource_id': 8798, 'quantity': 1}, {'resou...
#
#                                             image_urls
# 164  {'icon': 'https://api.dofusdu.de/dofus3/v1/img...
